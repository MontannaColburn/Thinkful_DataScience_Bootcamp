# %% [markdown]
# # Data Cleaning and Validation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv('Wellcome_APCspend2013.csv', encoding='ISO-8859-1') 
#https://stackoverflow.com/questions/21504319/python-3-csv-file-giving-unicodedecodeerror-utf-8-codec-cant-decode-byte-err 
df.head(10)
# Out:
#               PMID/PMCID                                     Publisher  \
# 0                    NaN                                           CUP
# 1             PMC3679557                                           ACS
# 2  23043264  PMC3506128                                            ACS
# 3    23438330 PMC3646402                                           ACS
# 4   23438216 PMC3601604                                            ACS
# 5             PMC3579457                                           ACS
# 6             PMC3709265                                           ACS
# 7   23057412 PMC3495574                                            ACS
# 8      PMCID: PMC3780468  ACS (Amercian Chemical Society) Publications
# 9      PMCID: PMC3621575  ACS (Amercian Chemical Society) Publications
#
#                     Journal title  \
# 0          Psychological Medicine
# 1               Biomacromolecules
# 2                      J Med Chem
# 3                      J Med Chem
# 4                      J Org Chem
# 5  Journal of Medicinal Chemistry
# 6    Journal of Proteome Research
# 7                       Mol Pharm
# 8            ACS Chemical Biology
# 9            ACS Chemical Biology
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
# 5  Comparative Structural and Functional Studies ...
# 6  Mapping Proteolytic Processing in the Secretom...
# 7  Quantitative silencing of EGFP reporter gene b...
# 8  A Novel Allosteric Inhibitor of the Uridine Di...
# 9  Chemical proteomic analysis reveals the drugab...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88
# 5                                           £2392.20
# 6                                           £2367.95
# 7                                            £649.33
# 8                                           £1294.59
# 9                                           £1294.78

# %%
df.rename(columns={'PMID/PMCID':'PMID/PMCID','Publisher':'Publisher','Journal title':'Journal_Title','Article title':'Article_Title','COST (£) charged to Wellcome (inc VAT when charged)':'Cost'}, inplace=True)

# %%
len(df)
# Out:
# 2127

# %%
#see how many unique ids we have without cleaning 
print(len(df['PMID/PMCID'].unique()))
print(len(df['Publisher'].unique()))
print(len(df['Journal_Title'].unique()))
print(len(df['Article_Title'].unique()))
# Out:
# 1881
# 299
# 985
# 2126

# %%
#Wellcome Trust asked institutions to cite the PMC ID (or the PubMed ID if a PMC ID is not known)
##need to try to consolidate the format into either PMID (8 digits) or PMCID (7 digits)

# %%
#remove whitespacing, create one coherent capitalization
df['PMID/PMCID'] = df['PMID/PMCID'].str.upper().str.strip()
print(len(df['PMID/PMCID'].unique()))
# Out:
# 1874

# %%
#replace duplicated values, one coherent capitalization, remove whitespacing 
df['Publisher'] = df['Publisher'].str.replace('ACS (Amercian Chemical Society) Publications', 'ACS') 
df['Publisher'] = df['Publisher'].str.replace('ACS Publications','ACS')
df['Publisher'] = df['Publisher'].str.replace('American Chemical Society','ACS')
df['Publisher'] = df['Publisher'].str.replace('American Society for Biochemistry and Molecular Biolgy', 'American Society for Biochemistry and Molecular Biology')
df['Publisher'] = df['Publisher'].str.replace('American Soc for Biochemistry and Molecular Biology','American Society for Biochemistry and Molecular Biology')
df['Publisher'] = df['Publisher'].str.upper().str.strip()
print(len(df['Publisher'].unique()))
# Out:
# 254

# %%
#check the values without cleaning 
df['Journal_Title'].value_counts().head(10)
# Out:
# PLoS One                                           92
# PLoS ONE                                           62
# Journal of Biological Chemistry                    48
# Nucleic Acids Research                             21
# Proceedings of the National Academy of Sciences    19
# Human Molecular Genetics                           18
# PLoS Neglected Tropical Diseases                   18
# Nature Communications                              17
# Neuroimage                                         15
# PLoS Genetics                                      15
# Name: Journal_Title, dtype: int64

# %%
#clean data 
df['Journal_Title'] = df['Journal_Title'].str.upper()
df['Journal_Title'] = df['Journal_Title'].str.replace('', '') 
df['Journal_Title'] = df['Journal_Title'].str.replace(',','')
df['Journal_Title'] = df['Journal_Title'].str.replace(':','')
df['Journal_Title'] = df['Journal_Title'].str.replace('-','')
df['Journal_Title'] = df['Journal_Title'].str.replace('.','')
df['Journal_Title'] = df['Journal_Title'].str.replace('&','and')
df['Journal_Title'] = df['Journal_Title'].str.replace("\)",'')
df['Journal_Title'] = df['Journal_Title'].str.replace("\(",'')
df['Journal_Title'] = df['Journal_Title'].str.strip()
print(len(df['Journal_Title'].unique()))
# Out:
# 891

# %%
#recheck values 
df['Journal_Title'].value_counts().head(10)
# Out:
# PLOS ONE                                           190
# JOURNAL OF BIOLOGICAL CHEMISTRY                     53
# NEUROIMAGE                                          29
# NUCLEIC ACIDS RESEARCH                              26
# PLOS PATHOGENS                                      24
# PLOS GENETICS                                       24
# PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES     22
# PLOS NEGLECTED TROPICAL DISEASES                    20
# NATURE COMMUNICATIONS                               19
# HUMAN MOLECULAR GENETICS                            19
# Name: Journal_Title, dtype: int64

# %%
df['Article_Title'] = df['Article_Title'].str.upper().str.strip()
print(len(df['Article_Title'].unique()))
# Out:
# 2126

# %%
#edit cost column
df['Cost']= df['Cost'].str.replace('£', '')
df['Cost']=df['Cost'].str.replace('$', '')
df['Cost']=df['Cost'].astype(float)

# %% [markdown]
# # Five most common journals and total articles each

# %%
df['Journal_Title'].value_counts().head(10)
# Out:
# PLOS ONE                                           190
# JOURNAL OF BIOLOGICAL CHEMISTRY                     53
# NEUROIMAGE                                          29
# NUCLEIC ACIDS RESEARCH                              26
# PLOS PATHOGENS                                      24
# PLOS GENETICS                                       24
# PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES     22
# PLOS NEGLECTED TROPICAL DISEASES                    20
# NATURE COMMUNICATIONS                               19
# HUMAN MOLECULAR GENETICS                            19
# Name: Journal_Title, dtype: int64

# %% [markdown]
# # Mean, median, and standard deviation of the open-access cost per article for each journal

# %%
df.groupby(['Journal_Title'])['Cost'].agg(['mean','median','std']).dropna()
# Out:
#                                                              mean      median  \
# Journal_Title
# ACS CHEMICAL BIOLOGY                                  1418.186000    1294.590
# ACS NANO                                               668.140000     668.140
# ACTA CRYSTALLOGRAPHICA SECTION F STRUCTURAL BIO...     796.635000     796.635
# ACTA NEUROPATHOLOGICA                                 2161.063333    2250.970
# ADDICTION                                             2136.225000    2136.225
# ADVANCES IN EXPERIMENTAL MEDICINE AND BIOLOGY         1928.457500    1928.460
# AGE                                                   2170.140000    2170.140
# AIDS                                                  2059.306667    1968.630
# AIDS CARE                                             2294.225000    2316.010
# AIDS UK                                               1836.920000    1836.920
# ALIMENTRARY PHARMACOLOGY and THERAPEUTICS             2373.590000    2373.590
# AMERICAN ETHNOLOGIST                                  1870.495000    1870.495
# AMERICAN JOURNAL OF EPIDEMIOLOGY                      1926.666667    2040.000
# AMERICAN JOURNAL OF HUMAN GENETICS                    2684.510000    2418.340
# AMERICAN JOURNAL OF PREVENTIVE MEDICINE               2196.690000    2377.650
# AMERICAN JOURNAL OF TRANSPLANTATION                   2052.946667    1900.700
# AMERICAN JOURNAL OF TROPICAL MEDICINE and HYGIENE     1648.006667    1646.360
# ANALYTICAL CHEMISTRY                                  1718.836667    2082.740
# ANGEWANDTE CHEMIE INTERNATIONAL EDITION               2437.190000    2437.190
# ANIMAL BEHAVIOUR                                      1811.380000    1811.380
# ANNALS OF NEUROLOGY                                   1996.236000    2010.240
# ANNALS OF THE NEW YORK ACADEMY OF SCIENCES            1896.635000    1896.635
# ANTIMICROBIAL AGENTS AND CHEMOTHERAPY                 1348.860000    1293.295
# ANTIOXIDANTS AND REDOX SIGNALING                      2105.290000    2105.290
# ARCHIVES OF DISEASE IN CHILDHOOD                      2140.000000    2040.000
# ARTHRITIS AND RHEUMATISM                              1500.000000    1500.000
# ARTHRITIS and RHEUMATISM                              1489.673333    1500.000
# ASIAN JOURNAL OF PSYCHIATRY                           2218.930000    2218.930
# ATHEROSCLEROSIS                                       2361.105000    2361.105
# BEHAVIOR RESEARCH AND THERAPY                         2273.730000    2273.730
# ...                                                           ...         ...
# SOCIAL HISTORY OF MEDICINE                            2055.000000    2040.000
# SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOL           1739.130000    1739.130
# SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOLOGY        2017.557500    1944.880
# SOCIAL SCIENCE AND MEDICINE                           1795.706000    1836.920
# SOCIAL SCIENCE and MEDICINE                           2113.770000    2113.770
# SOCIOLOGY OF HEALTH and ILLNESS                       1556.140000    1556.140
# STEM CELLS                                            1549.737500    1542.600
# STRUCTURE                                             3881.824286    3895.640
# THE AMERICAN JOURNAL OF HUMAN GENETICS                2437.452500    2130.890
# THE BIOCHEMICAL JOURNAL                               1800.000000    1800.000
# THE BRITISH JOURNAL OF PSYCHIATRY                     3000.000000    3000.000
# THE EMBO JOURNAL                                      2340.000000    2340.000
# THE FASEB JOURNAL                                     1431.690000    1615.915
# THE JOURNAL OF BIOLOGICAL CHEMISTRY                   1358.592857    1324.570
# THE JOURNAL OF NEUROSCIENCE                           2113.120000    2113.120
# THE LANCET                                            4558.003333    4554.010
# THE LANCET NEUROLOGY                                  5040.000000    5040.000
# THORAX                                                2040.000000    2040.000
# TRAFFIC                                               2129.338333    2273.455
# TRANSLATIONAL PSYCHIATRY                              2880.000000    2880.000
# TRENDS IN GENETICS                                    2370.935000    2370.935
# TRENDS IN NEUROSCIENCES                             501212.980000  501212.980
# TRENDS IN PARASITOLOGY                              251692.990000    2384.110
# TRIALS                                              200960.180000    1165.000
# TROPICAL MEDICINE AND INTERNATIONAL HEALTH            1843.163333    1883.625
# TUBERCULOSIS                                          2161.255000    2161.255
# VACCINE                                               1623.394000    1448.380
# VETERINARY PARASITOLOGY                             501243.585000  501243.585
# VIROLOGY                                              1928.505000    1928.505
# VISION RESEARCH                                     500727.590000  500727.590
#
#                                                               std
# Journal_Title
# ACS CHEMICAL BIOLOGY                                   507.309560
# ACS NANO                                                35.708892
# ACTA CRYSTALLOGRAPHICA SECTION F STRUCTURAL BIO...      15.605847
# ACTA NEUROPATHOLOGICA                                  244.811798
# ADDICTION                                              306.481292
# ADVANCES IN EXPERIMENTAL MEDICINE AND BIOLOGY            0.005000
# AGE                                                    237.785868
# AIDS                                                   281.067979
# AIDS CARE                                              126.415851
# AIDS UK                                                  0.000000
# ALIMENTRARY PHARMACOLOGY and THERAPEUTICS                0.000000
# AMERICAN ETHNOLOGIST                                     0.247487
# AMERICAN JOURNAL OF EPIDEMIOLOGY                       196.299092
# AMERICAN JOURNAL OF HUMAN GENETICS                     703.501205
# AMERICAN JOURNAL OF PREVENTIVE MEDICINE                313.431914
# AMERICAN JOURNAL OF TRANSPLANTATION                    278.022730
# AMERICAN JOURNAL OF TROPICAL MEDICINE and HYGIENE        2.852110
# ANALYTICAL CHEMISTRY                                   838.678951
# ANGEWANDTE CHEMIE INTERNATIONAL EDITION                  0.000000
# ANIMAL BEHAVIOUR                                         7.071068
# ANNALS OF NEUROLOGY                                    300.215371
# ANNALS OF THE NEW YORK ACADEMY OF SCIENCES             560.926596
# ANTIMICROBIAL AGENTS AND CHEMOTHERAPY                  115.343350
# ANTIOXIDANTS AND REDOX SIGNALING                       598.707312
# ARCHIVES OF DISEASE IN CHILDHOOD                       173.205081
# ARTHRITIS AND RHEUMATISM                                 0.000000
# ARTHRITIS and RHEUMATISM                               484.592530
# ASIAN JOURNAL OF PSYCHIATRY                            288.980399
# ATHEROSCLEROSIS                                         61.044528
# BEHAVIOR RESEARCH AND THERAPY                           87.172124
# ...                                                           ...
# SOCIAL HISTORY OF MEDICINE                              30.000000
# SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOL              0.000000
# SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOLOGY         172.267124
# SOCIAL SCIENCE AND MEDICINE                            600.217876
# SOCIAL SCIENCE and MEDICINE                            394.565584
# SOCIOLOGY OF HEALTH and ILLNESS                         59.453538
# STEM CELLS                                             220.013917
# STRUCTURE                                              166.835165
# THE AMERICAN JOURNAL OF HUMAN GENETICS                 868.682815
# THE BIOCHEMICAL JOURNAL                                  0.000000
# THE BRITISH JOURNAL OF PSYCHIATRY                        0.000000
# THE EMBO JOURNAL                                      1103.086579
# THE FASEB JOURNAL                                      406.966595
# THE JOURNAL OF BIOLOGICAL CHEMISTRY                    138.729897
# THE JOURNAL OF NEUROSCIENCE                            591.763523
# THE LANCET                                             240.024915
# THE LANCET NEUROLOGY                                  1018.233765
# THORAX                                                   0.000000
# TRAFFIC                                                340.691688
# TRANSLATIONAL PSYCHIATRY                                 0.000000
# TRENDS IN GENETICS                                       3.995153
# TRENDS IN NEUROSCIENCES                             705389.954206
# TRENDS IN PARASITOLOGY                              498870.709384
# TRIALS                                              446676.288070
# TROPICAL MEDICINE AND INTERNATIONAL HEALTH             161.141743
# TUBERCULOSIS                                           228.133861
# VACCINE                                                394.821486
# VETERINARY PARASITOLOGY                             705346.672200
# VIROLOGY                                               697.850753
# VISION RESEARCH                                     706076.399327
#
# [324 rows x 3 columns]
